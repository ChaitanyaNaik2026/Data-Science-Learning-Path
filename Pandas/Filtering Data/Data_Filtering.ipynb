# %%
import pandas as pd
import numpy as np

# %%
#Upload csv from laptop
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3c7d1332-71e6-44ea-8294-a2523c297921" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c7d1332-71e6-44ea-8294-a2523c297921">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_laptops = pd.read_csv('laptop.csv', encoding='cp1252')
df_laptops
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df_laptops.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %% [markdown]
# #Filter dataframe based on a condition

# %%
#find which rows have 'HP' in the 'company' column
df_laptops['Company'] == 'HP'
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301     True
# 1302    False
# Name: Company, Length: 1303, dtype: bool

# %%
#Filter df based on a condition
#syntax
df_laptops[df_laptops['Company'] == 'HP']
# Out:
#       laptop_ID Company                                  Product   TypeName  \
# 2             3      HP                                   250 G6   Notebook
# 10           11      HP                                   250 G6   Notebook
# 11           12      HP                                   250 G6   Notebook
# 22           23      HP                                   255 G6   Notebook
# 24           25      HP  15-BS101nv (i7-8550U/8GB/256GB/FHD/W10)  Ultrabook
# ...         ...     ...                                      ...        ...
# 1282       1300      HP                         Stream 11-Y000na    Netbook
# 1287       1305      HP      15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# 1294       1312      HP                      Pavilion 15-AW003nv   Notebook
# 1296       1314      HP                         Stream 11-Y000na    Netbook
# 1301       1319      HP      15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
#
# ...

# %%
#verify which companies are in the 'company' column with value_counts()
df_laptops[df_laptops['Company'] == 'HP'].value_counts('Company')
# Out:
# Company
# HP    274
# Name: count, dtype: int64

# %% [markdown]
# ##Exercise 1

# %%
df_laptops.head(10)
# Out:
#    laptop_ID Company          Product   TypeName  Inches  \
# 0          1   Apple      MacBook Pro  Ultrabook    13.3
# 1          2   Apple      Macbook Air  Ultrabook    13.3
# 2          3      HP           250 G6   Notebook    15.6
# 3          4   Apple      MacBook Pro  Ultrabook    15.4
# 4          5   Apple      MacBook Pro  Ultrabook    13.3
# 5          6    Acer         Aspire 3   Notebook    15.6
# 6          7   Apple      MacBook Pro  Ultrabook    15.4
# 7          8   Apple      Macbook Air  Ultrabook    13.3
# 8          9    Asus  ZenBook UX430UN  Ultrabook    14.0
# 9         10    Acer          Swift 3  Ultrabook    14.0
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# ...

# %%
#find which rows dont have apple in company column
df_laptops['Company'] != 'Apple'
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 1298     True
# 1299     True
# 1300     True
# 1301     True
# 1302     True
# Name: Company, Length: 1303, dtype: bool

# %%
#filter
df_laptops[df_laptops['Company'] != 'Apple'].value_counts('Company')
# Out:
# Company
# Lenovo       297
# Dell         297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Fujitsu        3
# LG             3
# Google         3
# Huawei         2
# Name: count, dtype: int64

# %% [markdown]
# ##Exercise 2

# %%
#Laptop with price greater then 2000
df_laptops['Price_euros'] > 2000
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Name: Price_euros, Length: 1303, dtype: bool

# %%
#filter
df_laptops[df_laptops['Price_euros'] > 2000]
# Out:
#       laptop_ID Company        Product   TypeName  Inches  \
# 3             4   Apple    MacBook Pro  Ultrabook    15.4
# 6             7   Apple    MacBook Pro  Ultrabook    15.4
# 12           13   Apple    MacBook Pro  Ultrabook    15.4
# 17           18   Apple    MacBook Pro  Ultrabook    15.4
# 58           59     MSI     GS73VR 7RG     Gaming    17.3
# ...         ...     ...            ...        ...     ...
# 1203       1221    Dell         XPS 13  Ultrabook    13.3
# 1209       1227    Asus      Rog Strix     Gaming    15.6
# 1231       1249   Razer      Blade Pro     Gaming    14.0
# 1236       1254      HP  EliteBook 840  Ultrabook    14.0
# 1247       1265    Asus    Rog GL502VS     Gaming    15.6
#
#                         ScreenResolution                          Cpu   Ram  \
# 3     IPS Panel Retina Display 2880x1800         Intel Core i7 2.7GHz  16GB
# 6     IPS Panel Retina Display 2880x1800         Intel Core i7 2.2GHz  16GB
# ...

# %% [markdown]
# #Creating a column based on 1 condition: np.where()

# %%
#Create an array based on price tiers
np.where(df_laptops['Price_euros'] > 2000, 'expensive', 'cheap')
# Out:
# array(['cheap', 'cheap', 'cheap', ..., 'cheap', 'cheap', 'cheap'],
#       dtype='<U9')

# %%
#Setting it to new column
df_laptops['price tier'] = np.where(df_laptops['Price_euros'] > 2000, 'expensive', 'cheap')

# %%
df_laptops.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
#Value count
df_laptops['price tier'].value_counts()
# Out:
# price tier
# cheap        1166
# expensive     137
# Name: count, dtype: int64

# %% [markdown]
# ##Exercise

# %%
#Create an array based on screen size
np.where(df_laptops['Inches'] > 15, 'big', 'small')
# Out:
# array(['small', 'small', 'big', ..., 'small', 'big', 'big'], dtype='<U5')

# %%
#set it to new column
df_laptops['Screen size'] = np.where(df_laptops['Inches'] > 15, 'big', 'small')

# %%
df_laptops.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
#value count
df_laptops['Screen size'].value_counts()
# Out:
# Screen size
# big      835
# small    468
# Name: count, dtype: int64

# %% [markdown]
# #Filter Dataframe based on 2 or more condition

# %%
#HP laptops cost more than 2000
(df_laptops['Company'] == 'HP') & (df_laptops['Price_euros'] > 2000)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Length: 1303, dtype: bool

# %% [markdown]
# ## &(And)

# %%
df_laptops[(df_laptops['Company'] == 'HP') & (df_laptops['Price_euros'] > 2000)]
# Out:
#       laptop_ID Company          Product            TypeName  Inches  \
# 146         149      HP  EliteBook Folio           Ultrabook    12.5
# 316         321      HP     Spectre x360  2 in 1 Convertible    13.3
# 736         744      HP         ZBook 15         Workstation    15.6
# 749         758      HP         Zbook 17         Workstation    17.3
# 800         809      HP         ZBook 17         Workstation    15.6
# 848         858      HP   EliteBook x360  2 in 1 Convertible    13.3
# 857         868      HP   EliteBook x360  2 in 1 Convertible    13.3
# 911         924      HP  Elitebook Folio           Ultrabook    12.5
# 950         964      HP     ZBook Studio         Workstation    15.6
# 999        1013      HP    EliteBook 840           Ultrabook    14.0
# 1019       1033      HP   EliteBook 1040            Notebook    14.0
# 1045       1059      HP    EliteBook 850            Notebook    15.6
# 1083       1098      HP     Spectre x360           Ultrabook    13.3
# ...

# %%
## (or)

# %%
# find laptops apple or dell
(df_laptops['Company'] == 'Apple') | (df_laptops['Company'] == 'Dell')
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Name: Company, Length: 1303, dtype: bool

# %%
#filter
df_laptops[(df_laptops['Company'] == 'Apple') | (df_laptops['Company'] == 'Dell')]
# Out:
#       laptop_ID Company        Product   TypeName  Inches  \
# 0             1   Apple    MacBook Pro  Ultrabook    13.3
# 1             2   Apple    Macbook Air  Ultrabook    13.3
# 3             4   Apple    MacBook Pro  Ultrabook    15.4
# 4             5   Apple    MacBook Pro  Ultrabook    13.3
# 6             7   Apple    MacBook Pro  Ultrabook    15.4
# ...         ...     ...            ...        ...     ...
# 1278       1296    Dell  Inspiron 3552   Notebook    15.6
# 1281       1299    Dell  Inspiron 3567   Notebook    15.6
# 1290       1308    Dell  Inspiron 3567   Notebook    15.6
# 1292       1310    Dell  Inspiron 3552   Notebook    15.6
# 1295       1313    Dell  Inspiron 3567   Notebook    15.6
#
#                         ScreenResolution  \
# 0     IPS Panel Retina Display 2560x1600
# 1                               1440x900
# 3     IPS Panel Retina Display 2880x1800
# 4     IPS Panel Retina Display 2560x1600
# 6     IPS Panel Retina Display 2880x1800
# ...

# %%
#value count
df_laptops[(df_laptops['Company'] == 'Apple') | (df_laptops['Company'] == 'Dell')].value_counts('Company')
# Out:
# Company
# Dell     297
# Apple     21
# Name: count, dtype: int64

# %%
#Find laptop from apple or dell costing over 2000
((df_laptops['Company'] == 'Apple') | (df_laptops['Company'] == 'Dell')) & (df_laptops['Price_euros'] > 2000)
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Length: 1303, dtype: bool

# %%
#filter
df_laptops[(df_laptops['Company'] == 'Apple') | (df_laptops['Company'] == 'Dell') & (df_laptops['Price_euros'] > 2000)]
# Out:
#       laptop_ID Company          Product            TypeName  Inches  \
# 0             1   Apple      MacBook Pro           Ultrabook    13.3
# 1             2   Apple      Macbook Air           Ultrabook    13.3
# 3             4   Apple      MacBook Pro           Ultrabook    15.4
# 4             5   Apple      MacBook Pro           Ultrabook    13.3
# 6             7   Apple      MacBook Pro           Ultrabook    15.4
# 7             8   Apple      Macbook Air           Ultrabook    13.3
# 12           13   Apple      MacBook Pro           Ultrabook    15.4
# 14           15   Apple      MacBook 12"           Ultrabook    12.0
# 15           16   Apple      MacBook Pro           Ultrabook    13.3
# 17           18   Apple      MacBook Pro           Ultrabook    15.4
# 26           27   Apple      MacBook Air           Ultrabook    13.3
# 34           35   Apple      MacBook Air           Ultrabook    13.3
# 45           46   Apple      MacBook Pro           Ultrabook    13.3
# ...

# %% [markdown]
# #Creating conditional column for more thn 2 choices np.select()

# %%
#create 'conditions' and 'value' variable
conditions = [
    df_laptops['Price_euros'] >3000,
    (df_laptops['Price_euros'] > 2000) & (df_laptops['Price_euros'] <= 3000),
    (df_laptops['Price_euros'] > 800) & (df_laptops['Price_euros'] <= 2000),
    df_laptops['Price_euros'] <= 800
]
values = [
    'Too expensive',
    'expensive',
    'Affordable',
    'cheap'
]

# %%
#set it to new column
df_laptops['price_tiers']  =np.select(conditions, values, default = 'Invalid price')

# %%
df_laptops
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
#count values inside 'price tiers'
df_laptops['price_tiers'].value_counts()
# Out:
# price_tiers
# Affordable       655
# cheap            511
# expensive        118
# Too expensive     19
# Name: count, dtype: int64

# %% [markdown]
# ##Exercise

# %%
#create an array based on multiple screen size
# Too big >16 , big>14 , small>12 ,Too small ,10
conditions= [
    df_laptops['Inches'] >16,
    (df_laptops['Inches']) >14 & (df_laptops['Inches'] <= 16),
    (df_laptops['Inches']) >12 & (df_laptops['Inches'] <= 14),
    (df_laptops['Inches']) >10
]
values = [
    'Too big',
    'big',
    'small',
    'Too small'
]

# %%
#set it to new column
df_laptops['Screen size'] = np.select(conditions, values, default = 'Invalid screen size')

# %%
#value counts
df_laptops['Screen size'].value_counts()
# Out:
# Screen size
# big        1137
# Too big     166
# Name: count, dtype: int64

# %%
df_laptops
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %% [markdown]
# #The .isin Method

# %% [markdown]
# ##Single fitering

# %%
#select Apple or HP laptops
df_laptops['Company'].isin(['Apple', 'HP'])
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301     True
# 1302    False
# Name: Company, Length: 1303, dtype: bool

# %%
#filer dataframes
df_laptops[df_laptops['Company'].isin(['Apple', 'HP'])].value_counts('Company')
# Out:
# Company
# HP       274
# Apple     21
# Name: count, dtype: int64

# %% [markdown]
# ##isin() : multiple filtering

# %%
#find notebooks or ultrabooks from apple or HP
filter1 = df_laptops['TypeName'].isin(['Notebook', 'Ultrabook'])
filter2 = df_laptops['Company'].isin(['Apple', 'HP'])

# %%
#Filter dataframe
df_laptops[filter1 & filter2]
# Out:
#       laptop_ID Company                              Product   TypeName  \
# 0             1   Apple                          MacBook Pro  Ultrabook
# 1             2   Apple                          Macbook Air  Ultrabook
# 2             3      HP                               250 G6   Notebook
# 3             4   Apple                          MacBook Pro  Ultrabook
# 4             5   Apple                          MacBook Pro  Ultrabook
# ...         ...     ...                                  ...        ...
# 1273       1291      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# 1280       1298      HP                  Pavilion 15-AW003nv   Notebook
# 1287       1305      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# 1294       1312      HP                  Pavilion 15-AW003nv   Notebook
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
#
#       Inches                    ScreenResolution                         Cpu  \
# ...

# %% [markdown]
# #Duplicate Rows with the .duplicate() Method

# %%
df_laptops.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %% [markdown]
# ##Example 1

# %%
#Find duplicates in 1 column/series
df_laptops.duplicated('laptop_ID')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Length: 1303, dtype: bool

# %%
#show element in dataframe wirh duplicate in column 'laptop_ID'
df_laptops[df_laptops.duplicated('laptop_ID')]
# Out:
# Empty DataFrame
# Columns: [laptop_ID, Company, Product, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price_euros, price tier, Screen size, price_tiers]
# Index: []

# %%
#Find duplicates in 2 or more columns
df_laptops.duplicated(['Product','TypeName','Inches'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1298     True
# 1299     True
# 1300     True
# 1301     True
# 1302     True
# Length: 1303, dtype: bool

# %%
duplicated =df_laptops.duplicated(['Product','TypeName','Inches'])

# %%
df_laptops[duplicated].sort_values(['Product','TypeName'])
# Out:
#       laptop_ID Company                              Product  \
# 1287       1305      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1098       1113      HP                               250 G5
# 1170       1188      HP                               250 G5
# 10           11      HP                               250 G6
# ...         ...     ...                                  ...
# 414         421    Asus                         ZenBook Flip
# 826         835    Asus                         ZenBook Flip
# 1275       1293    Asus                 ZenBook UX305CA-UBM1
# 1289       1307    Asus                 ZenBook UX305CA-UBM1
# 676         684    Asus                            Zenbook 3
#
#                 TypeName  Inches                           ScreenResolution  \
# 1287            Notebook    15.6                                   1366x768
# 1301            Notebook    15.6                                   1366x768
# ...

# %% [markdown]
# ##Example 2

# %% [markdown]
# ### Find the cheapest and most expensive laptop of each company using the sort_values() and duplicated()

# %%
#sort df ascending by company and price
df_laptops = df_laptops.sort_values(['Company','Price_euros'])
df_laptops
# Out:
#       laptop_ID Company                           Product   TypeName  Inches  \
# 1215       1233    Acer  C740-C9QX (3205U/2GB/32GB/Chrome    Netbook    11.6
# 290         295    Acer              Chromebook C910-C2ST   Notebook    15.6
# 1102       1117    Acer                     Chromebook 15   Notebook    15.6
# 695         703    Acer                 TravelMate B117-M    Netbook    11.6
# 1198       1216    Acer                          Aspire 3   Notebook    15.6
# ...         ...     ...                               ...        ...     ...
# 191         195    Vero     K147 (N3350/4GB/32GB/FHD/W10)   Notebook    14.0
# 877         888  Xiaomi                       Mi Notebook  Ultrabook    13.3
# 192         196  Xiaomi                       Mi Notebook  Ultrabook    13.3
# 184         188  Xiaomi                       Mi Notebook   Notebook    15.6
# 514         521  Xiaomi                       Mi Notebook   Notebook    15.6
#
# ...

# %%
#Cheak all value categories in 'Company' column
df_laptops['Company'].value_counts()
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Fujitsu        3
# LG             3
# Google         3
# Huawei         2
# Name: count, dtype: int64

# %%
#Duplicated values in 'Company' columns (default -> keep ="first")
duplicated_first= df_laptops.duplicated('Company',keep = 'first')

# %%
#show dataframe with duplicated values in 'Company' column
df_laptops[duplicated_first]

#keep='first'(cheapest laptop per company)
#Show dataframe with non duplicated values in 'Company' column
df_laptops[~duplicated_first][['Company','Price_euros']]
# Out:
#         Company  Price_euros
# 1215       Acer       174.00
# 1         Apple       898.94
# 20         Asus       191.90
# 30        Chuwi       244.99
# 340        Dell       274.90
# 983     Fujitsu       649.00
# 472      Google      1275.00
# 1268         HP       209.00
# 170      Huawei      1349.00
# 909          LG      1899.00
# 1272     Lenovo       229.00
# 1169        MSI       839.00
# 626    Mediacom       239.00
# 457   Microsoft       989.00
# 1117      Razer      1029.00
# 430     Samsung       269.00
# 159     Toshiba       447.00
# 1120       Vero       196.00
# 877      Xiaomi       935.00

# %%
#keep = 'last'
duplicated_last = df_laptops.duplicated('Company', keep = 'last')

# %%
#keep ='last'(most expensive laptop per company)
#show dataframe with non duplicated values in 'company' column
df_laptops[~duplicated_last][['Company','Price_euros']]
# Out:
#         Company  Price_euros
# 1189       Acer      2599.00
# 17        Apple      2858.00
# 1066       Asus      3975.00
# 421       Chuwi       449.00
# 723        Dell      3659.40
# 623     Fujitsu       799.00
# 437      Google      2199.00
# 749          HP      4389.00
# 214      Huawei      1499.00
# 678          LG      2299.00
# 610      Lenovo      4899.00
# 177         MSI      2799.00
# 580    Mediacom       389.00
# 449   Microsoft      2589.00
# 196       Razer      6099.00
# 874     Samsung      1849.00
# 491     Toshiba      2799.00
# 191        Vero       260.00
# 514      Xiaomi      1399.95

# %% [markdown]
# #Drop Duplicate elements with the .drop_duplicates() Method

# %%
#drop duplicates in 2 or more columns
df_laptops.drop_duplicates(['Company'])[['Company','Price_euros']]
# Out:
#         Company  Price_euros
# 1215       Acer       174.00
# 1         Apple       898.94
# 20         Asus       191.90
# 30        Chuwi       244.99
# 340        Dell       274.90
# 983     Fujitsu       649.00
# 472      Google      1275.00
# 1268         HP       209.00
# 170      Huawei      1349.00
# 909          LG      1899.00
# 1272     Lenovo       229.00
# 1169        MSI       839.00
# 626    Mediacom       239.00
# 457   Microsoft       989.00
# 1117      Razer      1029.00
# 430     Samsung       269.00
# 159     Toshiba       447.00
# 1120       Vero       196.00
# 877      Xiaomi       935.00

# %%
#sort dataframe ascending by company and price
#cheapest first and most expensive last
df_laptops =df_laptops.sort_values(['Company','Price_euros'])

# %%
#cheapest : keep=first
df_laptops.drop_duplicates(['Company'], keep = 'first')[['Company','Price_euros']]
# Out:
#         Company  Price_euros
# 1215       Acer       174.00
# 1         Apple       898.94
# 20         Asus       191.90
# 30        Chuwi       244.99
# 340        Dell       274.90
# 983     Fujitsu       649.00
# 472      Google      1275.00
# 1268         HP       209.00
# 170      Huawei      1349.00
# 909          LG      1899.00
# 1272     Lenovo       229.00
# 1169        MSI       839.00
# 626    Mediacom       239.00
# 457   Microsoft       989.00
# 1117      Razer      1029.00
# 430     Samsung       269.00
# 159     Toshiba       447.00
# 1120       Vero       196.00
# 877      Xiaomi       935.00

# %%
df_laptops.drop_duplicates(['Company'], keep = 'last', ignore_index=True)
# Out:
#     laptop_ID    Company                        Product     TypeName  Inches  \
# 0        1207       Acer                Predator G9-793       Gaming    17.3
# 1          18      Apple                    MacBook Pro    Ultrabook    15.4
# 2        1081       Asus                     ROG G701VO       Gaming    17.3
# 3         428      Chuwi                   LapBook 12.3     Notebook    12.3
# 4         731       Dell                   Alienware 17       Gaming    17.3
# 5         630    Fujitsu                  LifeBook A557     Notebook    15.6
# 6         444     Google                Pixelbook (Core    Ultrabook    12.3
# 7         758         HP                       Zbook 17  Workstation    17.3
# 8         219     Huawei                     MateBook X    Ultrabook    13.0
# 9         686         LG                    Gram 15Z975    Ultrabook    15.6
# 10        617     Lenovo                   Thinkpad P51     Notebook    15.6
# ...

# %% [markdown]
# ##Exercise 1

# %% [markdown]
# ###### find the biggest and smallest screen size in laptops of each company using the sort_values() methods (keep'first','last' and false)

# %%
#sort df ascending by company and inches
df_laptops = df_laptops.sort_values(['Company','Inches'])

# %%
#smallest keep=first
df_laptops.drop_duplicates(['Company'],keep='first')[['Company','Inches']]
# Out:
#         Company  Inches
# 1215       Acer    11.6
# 1234      Apple    11.6
# 20         Asus    11.6
# 421       Chuwi    12.3
# 584        Dell    11.6
# 983     Fujitsu    15.6
# 472      Google    12.3
# 1268         HP    11.6
# 170      Huawei    13.0
# 909          LG    14.0
# 50       Lenovo    10.1
# 1161        MSI    14.0
# 429    Mediacom    11.6
# 457   Microsoft    13.5
# 1117      Razer    12.5
# 430     Samsung    11.6
# 963     Toshiba    12.5
# 1120       Vero    13.3
# 877      Xiaomi    13.3

# %%
df_laptops.drop_duplicates(['Company'],keep='last')[['Company','Inches']]
# Out:
#         Company  Inches
# 1189       Acer    17.3
# 17        Apple    15.4
# 1066       Asus    17.3
# 483       Chuwi    15.6
# 723        Dell    17.3
# 623     Fujitsu    15.6
# 437      Google    12.3
# 749          HP    17.3
# 214      Huawei    13.0
# 678          LG    15.6
# 1081     Lenovo    17.3
# 177         MSI    18.4
# 580    Mediacom    14.0
# 449   Microsoft    13.5
# 196       Razer    17.3
# 593     Samsung    15.6
# 923     Toshiba    15.6
# 191        Vero    14.0
# 514      Xiaomi    15.6

# %% [markdown]
# #Get and count unique values using unique() and nunique() methods

# %% [markdown]
# ##unique()

# %%
#get unique elemnts in company col
df_laptops['Company'].unique()
# Out:
# array(['Acer', 'Apple', 'Asus', 'Chuwi', 'Dell', 'Fujitsu', 'Google',
#        'HP', 'Huawei', 'LG', 'Lenovo', 'MSI', 'Mediacom', 'Microsoft',
#        'Razer', 'Samsung', 'Toshiba', 'Vero', 'Xiaomi'], dtype=object)

# %%
#Inches column
df_laptops['Inches'].unique()
# Out:
# array([11.6, 13.3, 14. , 15.6, 17.3, 12. , 15.4, 12.5, 14.1, 12.3, 15. ,
#        17. , 13. , 10.1, 11.3, 13.9, 18.4, 13.5])

# %%
#length of unique elements
len(df_laptops['Inches'].unique())
# Out:
# 18

# %% [markdown]
# ##nunique()

# %%
#get number of unique elements in the object
#same as calculating using length function
df_laptops['Company'].nunique()
# Out:
# 19
