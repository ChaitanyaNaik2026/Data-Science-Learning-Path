# %% [markdown]
# # Hello World

# %%
print("Hello from Naik")
# Out:
# Hello from Naik

# %% [markdown]
# #Data type

# %%
type(2.4)
# Out:
# float

# %%
1+2
# Out:
# 3

# %%
type(True)
# Out:
# bool

# %% [markdown]
# #Methods

# %%
"hello".upper()
# Out:
# 'HELLO'

# %%
"hello".lower()
# Out:
# 'hello'

# %%
"hello".title()
# Out:
# 'Hello'

# %%
"hello".count('l')
# Out:
# 2

# %%
"hello".replace('h','y')
# Out:
# 'yello'

# %% [markdown]
# #Variables

# %%
message_1 = 'I am learning python'
message_1
# Out:
# 'I am learning python'

# %%
message_2 = 'and its fun'
message_2
# Out:
# 'and its fun'

# %%
message_1 +' ' + message_2
# Out:
# 'I am learning python and its fun'

# %%
f'{message_1} {message_2}'
# Out:
# 'I am learning python and its fun'

# %% [markdown]
# #List

# %%
country = ['India','Nepal','Usa','Spain']
country
# Out:
# ['India', 'Nepal', 'Usa', 'Spain']

# %%
country.append('Saudi')
country
# Out:
# ['India', 'Nepal', 'Usa', 'Spain', 'Saudi']

# %%
country[2]
# Out:
# 'Usa'

# %%
country[-2]
# Out:
# 'Spain'

# %%
#Slice
country[0:2]
# Out:
# ['India', 'Nepal']

# %% [markdown]
# ##Adding elements to list

# %%
country
# Out:
# ['India', 'Nepal', 'Usa', 'Spain', 'Saudi']

# %%
country.insert(8,'Portugal')

# %%
country
# Out:
# ['India', 'Nepal', 'Usa', 'Spain', 'Saudi', 'Portugal']

# %%
countries_2 = ['Argentina','Brazil']

# %%
country + countries_2
# Out:
# ['India', 'Nepal', 'Usa', 'Spain', 'Saudi', 'Portugal', 'Argentina', 'Brazil']

# %%
nested_list = [country,countries_2]

# %%
nested_list
# Out:
# [['India', 'Nepal', 'Usa', 'Spain', 'Saudi', 'Portugal'],
#  ['Argentina', 'Brazil']]

# %% [markdown]
# ##Removing an element

# %%
country
# Out:
# ['India', 'Nepal', 'Usa', 'Spain', 'Saudi', 'Portugal']

# %%
country.remove('Usa')

# %%
country
# Out:
# ['India', 'Nepal', 'Spain', 'Saudi', 'Portugal']

# %%
country.pop(4)
# Out:
# 'Portugal'

# %%
country
# Out:
# ['India', 'Nepal', 'Spain', 'Saudi']

# %%
del country[2]

# %%
country
# Out:
# ['India', 'Nepal', 'Saudi']

# %% [markdown]
# ##Sort a list

# %%
numbers =[5,4,3,2,1]

# %%
numbers.sort()

# %%
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers =[5,4,3,2,1]
numbers.sort(reverse=True)
numbers
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# ##Update Value in list

# %%
numbers[0] = 6
numbers
# Out:
# [6, 4, 3, 2, 1]

# %% [markdown]
# ##Copy of list

# %%
country
new_list = country[:]

# %%
new_list
# Out:
# ['India', 'Nepal', 'Saudi']

# %%
country.copy()
# Out:
# ['India', 'Nepal', 'Saudi']

# %%
new_list2 = country.copy()
new_list2
# Out:
# ['India', 'Nepal', 'Saudi']

# %% [markdown]
# #Dictionary

# %%
my_data ={'name':'Naik', 'age':30}
my_data
# Out:
# {'name': 'Naik', 'age': 30}

# %%
my_data.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
my_data.values()
# Out:
# dict_values(['Naik', 30])

# %%
my_data.items()
# Out:
# dict_items([('name', 'Naik'), ('age', 30)])

# %%
my_data['height']=5.8
my_data
# Out:
# {'name': 'Naik', 'age': 30, 'height': 5.8}

# %%
my_data.update({'height':5.7})
my_data
# Out:
# {'name': 'Naik', 'age': 30, 'height': 5.7}

# %% [markdown]
# ##Copy of Dict

# %%
new_dict=my_data.copy()
new_dict
# Out:
# {'name': 'Naik', 'age': 30, 'height': 5.7}

# %% [markdown]
# #Remove from Dict

# %%
my_data.pop('age')
my_data
# Out:
# {'name': 'Naik', 'height': 5.7}

# %%
del my_data['height']

# %%
my_data
# Out:
# {'name': 'Naik'}

# %% [markdown]
# #If statement

# %%
age = 32

if age>=18:
  print('You are an adult')
else:
  print('You are not a kid')
# Out:
# You are an adult

# %% [markdown]
# #For Loop

# %%
country
# Out:
# ['India', 'Nepal', 'Saudi']

# %%
for i,c in enumerate(country):
  print(i)
  print(c)
# Out:
# 0
# India
# 1
# Nepal
# 2
# Saudi

# %%
my_data
# Out:
# {'name': 'Naik'}

# %%
for key,value in my_data.items():
  print(key)
  print(value)
# Out:
# name
# Naik

# %% [markdown]
# #Function

# %%
def sum_values(a,b):
  x = a+b
  return x
print(sum_values(2,3))
# Out:
# 5

# %% [markdown]
# ##Built in functions

# %%
country
# Out:
# ['India', 'Nepal', 'Saudi']

# %%
len(country)
# Out:
# 3

# %%
max([1,2,3,4,5,6,7])
# Out:
# 7

# %%
min([2,3])
# Out:
# 2

# %%
type(country)
# Out:
# list

# %%
for i in range(1,5,3):
  print(i)
# Out:
# 1
# 4

# %% [markdown]
# # Module

# %%
import

# %% [markdown]
# ##OS Module

# %%
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.listdir()
# Out:
# ['.config', 'sample_data']

# %%
os.makedirs("new folder")

# %%
os.listdir()
# Out:
# ['.config', 'new folder', 'sample_data']
